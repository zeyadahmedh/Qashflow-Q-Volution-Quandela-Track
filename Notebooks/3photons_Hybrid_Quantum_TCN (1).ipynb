# %%
# !pip install aqora_cli
# Out:
# Collecting aqora_cli
#   Downloading aqora_cli-0.22.2-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (974 bytes)
# Requirement already satisfied: typing-extensions>=4.13.2 in /usr/local/lib/python3.12/dist-packages (from aqora_cli) (4.15.0)
# Collecting uv<1.0.0,>=0.3.2 (from aqora_cli)
#   Downloading uv-0.10.7-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Downloading aqora_cli-0.22.2-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 58.9 MB/s eta 0:00:00
# Downloading uv-0.10.7-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (23.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.2/23.2 MB 53.7 MB/s eta 0:00:00
# Installing collected packages: uv, aqora_cli
# Successfully installed aqora_cli-0.22.2 uv-0.10.7

# %%
# !pip install perceval-quandela torch scikit-learn polars pandas numpy matplotlib seaborn
# !pip install aqora-cli
# Out:
# Collecting perceval-quandela
#   Downloading perceval_quandela-1.1.0-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (2.10.0+cu128)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: polars in /usr/local/lib/python3.12/dist-packages (1.35.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.12/dist-packages (0.13.2)
# Requirement already satisfied: sympy~=1.12 in /usr/local/lib/python3.12/dist-packages (from perceval-quandela) (1.14.0)
# Requirement already satisfied: scipy~=1.13 in /usr/local/lib/python3.12/dist-packages (from perceval-quandela) (1.16.3)
# Requirement already satisfied: tabulate~=0.9 in /usr/local/lib/python3.12/dist-packages (from perceval-quandela) (0.9.0)
# Collecting exqalibur~=1.1.0 (from perceval-quandela)
#   Downloading exqalibur-1.1.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (430 bytes)
# Requirement already satisfied: multipledispatch<2 in /usr/local/lib/python3.12/dist-packages (from perceval-quandela) (1.0.0)
# Requirement already satisfied: protobuf>=3.20.3 in /usr/local/lib/python3.12/dist-packages (from perceval-quandela) (5.29.6)
# Collecting drawsvg>=2.0 (from perceval-quandela)
#   Downloading drawsvg-2.4.1-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: requests<3 in /usr/local/lib/python3.12/dist-packages (from perceval-quandela) (2.32.4)
# Requirement already satisfied: networkx<4,>=3.1 in /usr/local/lib/python3.12/dist-packages (from perceval-quandela) (3.6.1)
# Collecting latexcodec<4 (from perceval-quandela)
#   Downloading latexcodec-3.0.1-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: platformdirs<5 in /usr/local/lib/python3.12/dist-packages (from perceval-quandela) (4.9.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from perceval-quandela) (4.67.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch) (3.24.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch) (75.2.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch) (2025.3.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch) (1.3.5)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: polars-runtime-32==1.35.2 in /usr/local/lib/python3.12/dist-packages (from polars) (1.35.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3->perceval-quandela) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3->perceval-quandela) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3->perceval-quandela) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3->perceval-quandela) (2026.1.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy~=1.12->perceval-quandela) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch) (3.0.3)
# Downloading perceval_quandela-1.1.0-py3-none-any.whl (432 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 432.8/432.8 kB 1.7 MB/s eta 0:00:00
# Downloading drawsvg-2.4.1-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.1/44.1 kB 2.6 MB/s eta 0:00:00
# Downloading exqalibur-1.1.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 40.8 MB/s eta 0:00:00
# Downloading latexcodec-3.0.1-py3-none-any.whl (18 kB)
# Installing collected packages: drawsvg, latexcodec, exqalibur, perceval-quandela
# Successfully installed drawsvg-2.4.1 exqalibur-1.1.1 latexcodec-3.0.1 perceval-quandela-1.1.0
# Requirement already satisfied: aqora-cli in /usr/local/lib/python3.12/dist-packages (0.22.2)
# Requirement already satisfied: typing-extensions>=4.13.2 in /usr/local/lib/python3.12/dist-packages (from aqora-cli) (4.15.0)
# Requirement already satisfied: uv<1.0.0,>=0.3.2 in /usr/local/lib/python3.12/dist-packages (from aqora-cli) (0.10.7)

# %%
# !git clone https://github.com/merlinquantum/merlin.git
# %cd merlin
# !pip install -e ".[dev]"
# Out:
# Cloning into 'merlin'...
# remote: Enumerating objects: 8633, done.
# remote: Counting objects: 100% (2641/2641), done.
# remote: Compressing objects: 100% (595/595), done.
# remote: Total 8633 (delta 2240), reused 2050 (delta 2046), pack-reused 5992 (from 2)
# Receiving objects: 100% (8633/8633), 29.49 MiB | 16.92 MiB/s, done.
# Resolving deltas: 100% (6286/6286), done.
# /content/merlin
# Obtaining file:///content/merlin
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from merlinquantum==0.3.1) (2.10.0+cu128)
# Requirement already satisfied: perceval-quandela>=0.13.1 in /usr/local/lib/python3.12/dist-packages (from merlinquantum==0.3.1) (1.1.0)
# Collecting numpy>=2.2.6 (from merlinquantum==0.3.1)
#   Downloading numpy-2.4.2-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from merlinquantum==0.3.1) (2.2.2)
# Collecting scikit-learn>=1.7.2 (from merlinquantum==0.3.1)
#   Downloading scikit_learn-1.8.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: pytest>=8.0 in /usr/local/lib/python3.12/dist-packages (from merlinquantum==0.3.1) (8.4.2)
# Collecting pytest-benchmark>=4.0.0 (from merlinquantum==0.3.1)
#   Downloading pytest_benchmark-5.2.3-py3-none-any.whl.metadata (29 kB)
# Collecting pytest-cov>=5.0 (from merlinquantum==0.3.1)
#   Downloading pytest_cov-7.0.0-py3-none-any.whl.metadata (31 kB)
# Requirement already satisfied: ruff>=0.1.0 in /usr/local/lib/python3.12/dist-packages (from merlinquantum==0.3.1) (0.15.2)
# Collecting mypy>=1.0 (from merlinquantum==0.3.1)
#   Downloading mypy-1.19.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (2.2 kB)
# Requirement already satisfied: typing_extensions>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from mypy>=1.0->merlinquantum==0.3.1) (4.15.0)
# Collecting mypy_extensions>=1.0.0 (from mypy>=1.0->merlinquantum==0.3.1)
#   Downloading mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Collecting pathspec>=0.9.0 (from mypy>=1.0->merlinquantum==0.3.1)
#   Downloading pathspec-1.0.4-py3-none-any.whl.metadata (13 kB)
# Collecting librt>=0.6.2 (from mypy>=1.0->merlinquantum==0.3.1)
#   Downloading librt-0.8.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (1.3 kB)
# Requirement already satisfied: sympy~=1.12 in /usr/local/lib/python3.12/dist-packages (from perceval-quandela>=0.13.1->merlinquantum==0.3.1) (1.14.0)
# Requirement already satisfied: scipy~=1.13 in /usr/local/lib/python3.12/dist-packages (from perceval-quandela>=0.13.1->merlinquantum==0.3.1) (1.16.3)
# Requirement already satisfied: tabulate~=0.9 in /usr/local/lib/python3.12/dist-packages (from perceval-quandela>=0.13.1->merlinquantum==0.3.1) (0.9.0)
# Requirement already satisfied: matplotlib<4 in /usr/local/lib/python3.12/dist-packages (from perceval-quandela>=0.13.1->merlinquantum==0.3.1) (3.10.0)
# Requirement already satisfied: exqalibur~=1.1.0 in /usr/local/lib/python3.12/dist-packages (from perceval-quandela>=0.13.1->merlinquantum==0.3.1) (1.1.1)
# Requirement already satisfied: multipledispatch<2 in /usr/local/lib/python3.12/dist-packages (from perceval-quandela>=0.13.1->merlinquantum==0.3.1) (1.0.0)
# Requirement already satisfied: protobuf>=3.20.3 in /usr/local/lib/python3.12/dist-packages (from perceval-quandela>=0.13.1->merlinquantum==0.3.1) (5.29.6)
# Requirement already satisfied: drawsvg>=2.0 in /usr/local/lib/python3.12/dist-packages (from perceval-quandela>=0.13.1->merlinquantum==0.3.1) (2.4.1)
# Requirement already satisfied: requests<3 in /usr/local/lib/python3.12/dist-packages (from perceval-quandela>=0.13.1->merlinquantum==0.3.1) (2.32.4)
# Requirement already satisfied: networkx<4,>=3.1 in /usr/local/lib/python3.12/dist-packages (from perceval-quandela>=0.13.1->merlinquantum==0.3.1) (3.6.1)
# Requirement already satisfied: latexcodec<4 in /usr/local/lib/python3.12/dist-packages (from perceval-quandela>=0.13.1->merlinquantum==0.3.1) (3.0.1)
# Requirement already satisfied: platformdirs<5 in /usr/local/lib/python3.12/dist-packages (from perceval-quandela>=0.13.1->merlinquantum==0.3.1) (4.9.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from perceval-quandela>=0.13.1->merlinquantum==0.3.1) (4.67.3)
# Requirement already satisfied: iniconfig>=1 in /usr/local/lib/python3.12/dist-packages (from pytest>=8.0->merlinquantum==0.3.1) (2.3.0)
# Requirement already satisfied: packaging>=20 in /usr/local/lib/python3.12/dist-packages (from pytest>=8.0->merlinquantum==0.3.1) (26.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /usr/local/lib/python3.12/dist-packages (from pytest>=8.0->merlinquantum==0.3.1) (1.6.0)
# Requirement already satisfied: pygments>=2.7.2 in /usr/local/lib/python3.12/dist-packages (from pytest>=8.0->merlinquantum==0.3.1) (2.19.2)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.12/dist-packages (from pytest-benchmark>=4.0.0->merlinquantum==0.3.1) (9.0.0)
# Collecting coverage>=7.10.6 (from coverage[toml]>=7.10.6->pytest-cov>=5.0->merlinquantum==0.3.1)
#   Downloading coverage-7.13.4-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (8.5 kB)
# Requirement already satisfied: joblib>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.7.2->merlinquantum==0.3.1) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.7.2->merlinquantum==0.3.1) (3.6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->merlinquantum==0.3.1) (3.24.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->merlinquantum==0.3.1) (75.2.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->merlinquantum==0.3.1) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->merlinquantum==0.3.1) (2025.3.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->merlinquantum==0.3.1) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->merlinquantum==0.3.1) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->merlinquantum==0.3.1) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->merlinquantum==0.3.1) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->merlinquantum==0.3.1) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->merlinquantum==0.3.1) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->merlinquantum==0.3.1) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->merlinquantum==0.3.1) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->merlinquantum==0.3.1) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->merlinquantum==0.3.1) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->merlinquantum==0.3.1) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->merlinquantum==0.3.1) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->merlinquantum==0.3.1) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->merlinquantum==0.3.1) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->merlinquantum==0.3.1) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->merlinquantum==0.3.1) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->merlinquantum==0.3.1) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch>=2.0.0->merlinquantum==0.3.1) (1.3.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->merlinquantum==0.3.1) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->merlinquantum==0.3.1) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->merlinquantum==0.3.1) (2025.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4->perceval-quandela>=0.13.1->merlinquantum==0.3.1) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4->perceval-quandela>=0.13.1->merlinquantum==0.3.1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4->perceval-quandela>=0.13.1->merlinquantum==0.3.1) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4->perceval-quandela>=0.13.1->merlinquantum==0.3.1) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4->perceval-quandela>=0.13.1->merlinquantum==0.3.1) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4->perceval-quandela>=0.13.1->merlinquantum==0.3.1) (3.3.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->merlinquantum==0.3.1) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3->perceval-quandela>=0.13.1->merlinquantum==0.3.1) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3->perceval-quandela>=0.13.1->merlinquantum==0.3.1) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3->perceval-quandela>=0.13.1->merlinquantum==0.3.1) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3->perceval-quandela>=0.13.1->merlinquantum==0.3.1) (2026.1.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy~=1.12->perceval-quandela>=0.13.1->merlinquantum==0.3.1) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.0.0->merlinquantum==0.3.1) (3.0.3)
# Downloading mypy-1.19.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (13.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.6/13.6 MB 113.5 MB/s eta 0:00:00
# Downloading numpy-2.4.2-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 105.1 MB/s eta 0:00:00
# Downloading pytest_benchmark-5.2.3-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.3/45.3 kB 4.7 MB/s eta 0:00:00
# Downloading pytest_cov-7.0.0-py3-none-any.whl (22 kB)
# Downloading scikit_learn-1.8.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (8.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 106.1 MB/s eta 0:00:00
# Downloading coverage-7.13.4-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (254 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 254.1/254.1 kB 29.7 MB/s eta 0:00:00
# Downloading librt-0.8.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (224 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 26.5 MB/s eta 0:00:00
# Downloading mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Downloading pathspec-1.0.4-py3-none-any.whl (55 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 kB 6.5 MB/s eta 0:00:00
# Building wheels for collected packages: merlinquantum
#   Building editable for merlinquantum (pyproject.toml) ... done
#   Created wheel for merlinquantum: filename=merlinquantum-0.3.1-0.editable-py3-none-any.whl size=5850 sha256=4b0abfb2ea33d564c1aa7f6f3410a8b91584e36e85b5f3b09b20a130f3035345
#   Stored in directory: /tmp/pip-ephem-wheel-cache-pmhz345q/wheels/41/ac/06/fe46281cdb5efbef056c42f88f907722725b2124bd4d2f426a
# Successfully built merlinquantum
# Installing collected packages: pathspec, numpy, mypy_extensions, librt, coverage, pytest-benchmark, mypy, scikit-learn, pytest-cov, merlinquantum
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.6.1
#     Uninstalling scikit-learn-1.6.1:
#       Successfully uninstalled scikit-learn-1.6.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.19.0 requires numpy<2.2.0,>=1.26.0, but you have numpy 2.4.2 which is incompatible.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.4.2 which is incompatible.
# Successfully installed coverage-7.13.4 librt-0.8.1 merlinquantum-0.3.1 mypy-1.19.1 mypy_extensions-1.1.0 numpy-2.4.2 pathspec-1.0.4 pytest-benchmark-5.2.3 pytest-cov-7.0.0 scikit-learn-1.8.0

# %%
# !pip install merlinquantum
# Out:
# Requirement already satisfied: merlinquantum in /usr/local/lib/python3.12/dist-packages (0.3.1)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from merlinquantum) (2.10.0+cu128)
# Requirement already satisfied: perceval-quandela>=0.13.1 in /usr/local/lib/python3.12/dist-packages (from merlinquantum) (1.1.0)
# Requirement already satisfied: numpy>=2.2.6 in /usr/local/lib/python3.12/dist-packages (from merlinquantum) (2.4.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from merlinquantum) (2.2.2)
# Requirement already satisfied: scikit-learn>=1.7.2 in /usr/local/lib/python3.12/dist-packages (from merlinquantum) (1.8.0)
# Requirement already satisfied: sympy~=1.12 in /usr/local/lib/python3.12/dist-packages (from perceval-quandela>=0.13.1->merlinquantum) (1.14.0)
# Requirement already satisfied: scipy~=1.13 in /usr/local/lib/python3.12/dist-packages (from perceval-quandela>=0.13.1->merlinquantum) (1.16.3)
# Requirement already satisfied: tabulate~=0.9 in /usr/local/lib/python3.12/dist-packages (from perceval-quandela>=0.13.1->merlinquantum) (0.9.0)
# Requirement already satisfied: matplotlib<4 in /usr/local/lib/python3.12/dist-packages (from perceval-quandela>=0.13.1->merlinquantum) (3.10.0)
# Requirement already satisfied: exqalibur~=1.1.0 in /usr/local/lib/python3.12/dist-packages (from perceval-quandela>=0.13.1->merlinquantum) (1.1.1)
# Requirement already satisfied: multipledispatch<2 in /usr/local/lib/python3.12/dist-packages (from perceval-quandela>=0.13.1->merlinquantum) (1.0.0)
# Requirement already satisfied: protobuf>=3.20.3 in /usr/local/lib/python3.12/dist-packages (from perceval-quandela>=0.13.1->merlinquantum) (5.29.6)
# Requirement already satisfied: drawsvg>=2.0 in /usr/local/lib/python3.12/dist-packages (from perceval-quandela>=0.13.1->merlinquantum) (2.4.1)
# Requirement already satisfied: requests<3 in /usr/local/lib/python3.12/dist-packages (from perceval-quandela>=0.13.1->merlinquantum) (2.32.4)
# Requirement already satisfied: networkx<4,>=3.1 in /usr/local/lib/python3.12/dist-packages (from perceval-quandela>=0.13.1->merlinquantum) (3.6.1)
# Requirement already satisfied: latexcodec<4 in /usr/local/lib/python3.12/dist-packages (from perceval-quandela>=0.13.1->merlinquantum) (3.0.1)
# Requirement already satisfied: platformdirs<5 in /usr/local/lib/python3.12/dist-packages (from perceval-quandela>=0.13.1->merlinquantum) (4.9.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from perceval-quandela>=0.13.1->merlinquantum) (4.67.3)
# Requirement already satisfied: joblib>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.7.2->merlinquantum) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.7.2->merlinquantum) (3.6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->merlinquantum) (3.24.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->merlinquantum) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->merlinquantum) (75.2.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->merlinquantum) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->merlinquantum) (2025.3.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->merlinquantum) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->merlinquantum) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->merlinquantum) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->merlinquantum) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->merlinquantum) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->merlinquantum) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->merlinquantum) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->merlinquantum) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->merlinquantum) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->merlinquantum) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->merlinquantum) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->merlinquantum) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->merlinquantum) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->merlinquantum) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->merlinquantum) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->merlinquantum) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->merlinquantum) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch>=2.0.0->merlinquantum) (1.3.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->merlinquantum) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->merlinquantum) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->merlinquantum) (2025.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4->perceval-quandela>=0.13.1->merlinquantum) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4->perceval-quandela>=0.13.1->merlinquantum) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4->perceval-quandela>=0.13.1->merlinquantum) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4->perceval-quandela>=0.13.1->merlinquantum) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4->perceval-quandela>=0.13.1->merlinquantum) (26.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4->perceval-quandela>=0.13.1->merlinquantum) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4->perceval-quandela>=0.13.1->merlinquantum) (3.3.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->merlinquantum) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3->perceval-quandela>=0.13.1->merlinquantum) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3->perceval-quandela>=0.13.1->merlinquantum) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3->perceval-quandela>=0.13.1->merlinquantum) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3->perceval-quandela>=0.13.1->merlinquantum) (2026.1.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy~=1.12->perceval-quandela>=0.13.1->merlinquantum) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.0.0->merlinquantum) (3.0.3)

# %%
import aqora_cli
import polars as pl
from aqora_cli.pyarrow import dataset

df_raw= pl.scan_pyarrow_dataset(dataset("quandela/challenge-swpations", "v0.0.0")).collect()

# %%
df_raw
# Out:
# shape: (494, 225)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ Date      ┆ Tenor :   ┆ Tenor :   ┆ Tenor :   ┆ … ┆ Tenor :   ┆ Tenor :   ┆ Tenor :   ┆ Tenor :  │
# │ ---       ┆ 10;       ┆ 10;       ┆ 10;       ┆   ┆ 9;        ┆ 9;        ┆ 9;        ┆ 9;       │
# │ str       ┆ Maturity  ┆ Maturity  ┆ Maturity  ┆   ┆ Maturity  ┆ Maturity  ┆ Maturity  ┆ Maturity │
# │           ┆ :         ┆ : 0.25    ┆ : 0.5     ┆   ┆ : 30      ┆ : 4       ┆ : 5       ┆ : 7      │
# │           ┆ 0.08333…  ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---      │
# │           ┆ ---       ┆ f64       ┆ f64       ┆   ┆ f64       ┆ f64       ┆ f64       ┆ f64      │
# │           ┆ f64       ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 01/01/205 ┆ 0.035595  ┆ 0.062605  ┆ 0.086316  ┆ … ┆ 0.325758  ┆ 0.210623  ┆ 0.227303  ┆ 0.244883 │
# │ 0         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 02/01/205 ┆ 0.036437  ┆ 0.063971  ┆ 0.088105  ┆ … ┆ 0.331462  ┆ 0.213865  ┆ 0.230482  ┆ 0.247743 │
# │ 0         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 03/01/205 ┆ 0.036062  ┆ 0.063423  ┆ 0.087443  ┆ … ┆ 0.32871   ┆ 0.212728  ┆ 0.229364  ┆ 0.246572 │
# │ 0         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 05/01/205 ┆ 0.037793  ┆ 0.066153  ┆ 0.090882  ┆ … ┆ 0.332811  ┆ 0.2174    ┆ 0.233763  ┆ 0.24996  │
# │ 0         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 06/01/205 ┆ 0.037492  ┆ 0.065709  ┆ 0.090328  ┆ … ┆ 0.329123  ┆ 0.216163  ┆ 0.232518  ┆ 0.248582 │
# │ 0         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …        │
# │ 17/12/205 ┆ 0.031444  ┆ 0.056864  ┆ 0.079999  ┆ … ┆ 0.331625  ┆ 0.20723   ┆ 0.224698  ┆ 0.243051 │
# │ 1         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 18/12/205 ┆ 0.031783  ┆ 0.05735   ┆ 0.080564  ┆ … ┆ 0.333177  ┆ 0.207973  ┆ 0.225418  ┆ 0.243836 │
# │ 1         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 20/12/205 ┆ 0.03222   ┆ 0.057977  ┆ 0.081282  ┆ … ┆ 0.333384  ┆ 0.208594  ┆ 0.225973  ┆ 0.244342 │
# │ 1         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 21/12/205 ┆ 0.033274  ┆ 0.059634  ┆ 0.083363  ┆ … ┆ 0.3357    ┆ 0.211396  ┆ 0.22863   ┆ 0.246488 │
# │ 1         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 23/12/205 ┆ 0.034372  ┆ 0.061477  ┆ 0.085806  ┆ … ┆ 0.339576  ┆ 0.215304  ┆ 0.232393  ┆ 0.24942  │
# │ 1         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
# When you have the actual dataset, simply replace the data loading part:
df_raw = pl.scan_pyarrow_dataset(dataset("quandela/challenge-swpations", "v0.0.0")).collect()
df = df_raw.to_pandas()
# The Date column will be automatically handled

# %%
# !pip uninstall -y torch torchvision torchaudio
# !pip install torch==2.3.1 torchvision==0.18.1 torchaudio==2.3.1
# Out:
# WARNING: Skipping torch as it is not installed.
# WARNING: Skipping torchvision as it is not installed.
# WARNING: Skipping torchaudio as it is not installed.
# Collecting torch==2.3.1
#   Downloading torch-2.3.1-cp312-cp312-manylinux1_x86_64.whl.metadata (26 kB)
# Collecting torchvision==0.18.1
#   Downloading torchvision-0.18.1-cp312-cp312-manylinux1_x86_64.whl.metadata (6.6 kB)
# Collecting torchaudio==2.3.1
#   Downloading torchaudio-2.3.1-cp312-cp312-manylinux1_x86_64.whl.metadata (6.4 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch==2.3.1) (3.24.3)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.12/dist-packages (from torch==2.3.1) (4.15.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.12/dist-packages (from torch==2.3.1) (1.14.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch==2.3.1) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch==2.3.1) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch==2.3.1) (2025.3.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch==2.3.1)
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch==2.3.1)
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch==2.3.1)
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch==2.3.1)
#   Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch==2.3.1)
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch==2.3.1)
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch==2.3.1)
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch==2.3.1)
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch==2.3.1)
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch==2.3.1)
#   Downloading nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch==2.3.1)
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.7 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from torchvision==0.18.1) (2.4.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchvision==0.18.1) (11.3.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.12/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch==2.3.1) (12.8.93)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch==2.3.1) (3.0.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy->torch==2.3.1) (1.3.0)
# Downloading torch-2.3.1-cp312-cp312-manylinux1_x86_64.whl (779.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 779.1/779.1 MB 1.6 MB/s eta 0:00:00
# Downloading torchvision-0.18.1-cp312-cp312-manylinux1_x86_64.whl (7.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 94.1 MB/s eta 0:00:00
# Downloading torchaudio-2.3.1-cp312-cp312-manylinux1_x86_64.whl (3.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 101.4 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 3.8 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 104.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 87.1 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 66.9 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 1.2 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 7.7 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 14.6 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 8.2 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 6.4 MB/s eta 0:00:00
# Downloading nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.2/176.2 MB 6.3 MB/s eta 0:00:00
# Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 11.1 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nccl-cu12, nvidia-cusparse-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusolver-cu12, nvidia-cudnn-cu12, torch, torchvision, torchaudio
#   Attempting uninstall: nvidia-nvtx-cu12
#     Found existing installation: nvidia-nvtx-cu12 12.8.90
#     Uninstalling nvidia-nvtx-cu12-12.8.90:
#       Successfully uninstalled nvidia-nvtx-cu12-12.8.90
#   Attempting uninstall: nvidia-nccl-cu12
#     Found existing installation: nvidia-nccl-cu12 2.27.5
#     Uninstalling nvidia-nccl-cu12-2.27.5:
#       Successfully uninstalled nvidia-nccl-cu12-2.27.5
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.8.93
#     Uninstalling nvidia-cusparse-cu12-12.5.8.93:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.8.93
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.9.90
#     Uninstalling nvidia-curand-cu12-10.3.9.90:
#       Successfully uninstalled nvidia-curand-cu12-10.3.9.90
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.3.3.83
#     Uninstalling nvidia-cufft-cu12-11.3.3.83:
#       Successfully uninstalled nvidia-cufft-cu12-11.3.3.83
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.8.90
#     Uninstalling nvidia-cuda-runtime-cu12-12.8.90:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.8.90
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.8.93
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.8.93:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.8.93
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.8.90
#     Uninstalling nvidia-cuda-cupti-cu12-12.8.90:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.8.90
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.8.4.1
#     Uninstalling nvidia-cublas-cu12-12.8.4.1:
#       Successfully uninstalled nvidia-cublas-cu12-12.8.4.1
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.7.3.90
#     Uninstalling nvidia-cusolver-cu12-11.7.3.90:
#       Successfully uninstalled nvidia-cusolver-cu12-11.7.3.90
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.10.2.21
#     Uninstalling nvidia-cudnn-cu12-9.10.2.21:
#       Successfully uninstalled nvidia-cudnn-cu12-9.10.2.21
# Successfully installed nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvtx-cu12-12.1.105 torch-2.3.1 torchaudio-2.3.1 torchvision-0.18.1

# %%
import os
os.kill(os.getpid(), 9)

# %%
"""
Quantum Machine Learning for Option Pricing
Fixed version with explicit device handling for quantum layer outputs
"""

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from tqdm import tqdm
import math
import os
from datetime import datetime

# Import only what we know exists from documentation
from merlin import (
    QuantumLayer,
    MeasurementStrategy,
    ComputationSpace,
    LexGrouping,
    ModGrouping
)
import perceval as pcvl

# Set random seeds for reproducibility
torch.manual_seed(42)
np.random.seed(42)

class ScaleLayer(nn.Module):
    """
    Scale input values to appropriate range for quantum circuit
    """
    def __init__(self, dim, scale_type="learned"):
        super().__init__()
        if scale_type == "learned":
            self.scale = nn.Parameter(torch.full((dim,), 0.1))
        elif scale_type == "pi":
            self.scale = torch.full((dim,), torch.pi)
        elif scale_type == "2pi":
            self.scale = torch.full((dim,), 2 * torch.pi)
        else:
            self.scale = torch.full((dim,), 1.0)

    def forward(self, x):
        return x * self.scale

class Chomp1d(nn.Module):
    """
    Chomp1d module for causal convolutions
    Removes excess padding from the right side
    """
    def __init__(self, chomp_size):
        super().__init__()
        self.chomp_size = chomp_size

    def forward(self, x):
        return x[:, :, :-self.chomp_size].contiguous()

class TemporalBlock(nn.Module):
    """
    Temporal Block for TCN
    Consists of two dilated causal convolutions with residual connection
    """
    def __init__(self, n_inputs, n_outputs, kernel_size, stride, dilation, padding, dropout=0.2):
        super().__init__()

        # First convolution
        self.conv1 = nn.Conv1d(
            n_inputs, n_outputs, kernel_size,
            stride=stride, padding=padding, dilation=dilation
        )
        self.chomp1 = Chomp1d(padding)
        self.relu1 = nn.ReLU()
        self.dropout1 = nn.Dropout(dropout)

        # Second convolution
        self.conv2 = nn.Conv1d(
            n_outputs, n_outputs, kernel_size,
            stride=stride, padding=padding, dilation=dilation
        )
        self.chomp2 = Chomp1d(padding)
        self.relu2 = nn.ReLU()
        self.dropout2 = nn.Dropout(dropout)

        # Residual connection
        self.net = nn.Sequential(
            self.conv1, self.chomp1, self.relu1, self.dropout1,
            self.conv2, self.chomp2, self.relu2, self.dropout2
        )

        # Downsample if input and output dimensions differ
        self.downsample = nn.Conv1d(n_inputs, n_outputs, 1) if n_inputs != n_outputs else None
        self.relu = nn.ReLU()

    def forward(self, x):
        out = self.net(x)
        res = x if self.downsample is None else self.downsample(x)
        return self.relu(out + res)

class TemporalConvNet(nn.Module):
    """
    Temporal Convolutional Network
    """
    def __init__(self, num_inputs, num_channels, kernel_size=3, dropout=0.2):
        super().__init__()

        layers = []
        num_levels = len(num_channels)

        for i in range(num_levels):
            dilation_size = 2 ** i
            in_channels = num_inputs if i == 0 else num_channels[i-1]
            out_channels = num_channels[i]

            layers.append(
                TemporalBlock(
                    in_channels, out_channels, kernel_size,
                    stride=1, dilation=dilation_size,
                    padding=(kernel_size - 1) * dilation_size,
                    dropout=dropout
                )
            )

        self.network = nn.Sequential(*layers)

    def forward(self, x):
        """
        Args:
            x: [batch_size, channels, sequence_length]
        Returns:
            [batch_size, channels, sequence_length]
        """
        return self.network(x)

def create_circuit_general(modes=6):
    """
    Create a variational quantum circuit with specified number of modes
    """
    # Left interferometer with trainable parameters
    wl = pcvl.GenericInterferometer(
        modes,
        lambda i: (
            pcvl.BS(pcvl.P(f"theta_li{i}_bs"))
            // pcvl.PS(pcvl.P(f"theta_li_ps{i}"))
            // pcvl.BS(pcvl.P(f"theta_lo{i}_bs"))
            // pcvl.PS(pcvl.P(f"theta_lo_ps{i}"))
        ),
        shape=pcvl.InterferometerShape.RECTANGLE,
    )

    # Variable phase shifters for input encoding
    c_var = pcvl.Circuit(modes)
    # We'll encode features in all modes
    for i in range(modes):
        px = pcvl.P(f"px{i}")
        c_var.add(i, pcvl.PS(px))

    # Right interferometer with trainable parameters
    wr = pcvl.GenericInterferometer(
        modes,
        lambda i: (
            pcvl.BS(pcvl.P(f"theta_ri{i}_bs"))
            // pcvl.PS(pcvl.P(f"theta_ri{i}_ps"))
            // pcvl.BS(pcvl.P(f"theta_ro{i}_bs"))
            // pcvl.PS(pcvl.P(f"theta_ro{i}_ps"))
        ),
        shape=pcvl.InterferometerShape.RECTANGLE,
    )

    # Combine all components
    c = pcvl.Circuit(modes)
    c.add(0, wl, merge=True)
    c.add(0, c_var, merge=True)
    c.add(0, wr, merge=True)

    return c

class QuantumFinancialTCN(nn.Module):
    """
    Hybrid Quantum-Classical Model for Option Pricing using Temporal Convolutional Network
    """

    def __init__(self, n_features=200, q_modes=6, n_photons=3,  # Changed to 3 photons
                 hidden_channels=[64, 128, 64], kernel_size=3, dropout=0.1):
        super().__init__()

        # Store dimensions
        self.n_features = n_features
        self.q_modes = q_modes
        self.n_photons = n_photons  # Store photon count
        self.hidden_channels = hidden_channels
        self.kernel_size = kernel_size
        self.dropout = dropout

        # Step 1: Classical compression (n_features -> q_modes)
        self.compressor = nn.Sequential(
            nn.Linear(n_features, 64),
            nn.ReLU(),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Linear(32, q_modes),
            nn.Tanh()  # Bound to [-1, 1] for phase encoders
        )

        # Step 2: Scale layer
        self.scale_layer = ScaleLayer(q_modes, scale_type="learned")

        # Step 3: Create quantum circuit
        print(f"Creating quantum circuit with {q_modes} modes, {n_photons} photons...")
        circuit = create_circuit_general(modes=q_modes)

        # Create input state based on photon distribution
        input_state = [1] * n_photons + [0] * (q_modes - n_photons)
        print(f"Input state: {input_state}")

        # Create quantum layer
        self.quantum_layer = QuantumLayer(
            input_size=q_modes,
            circuit=circuit,
            trainable_parameters=["theta"],
            input_parameters=["px"],
            input_state=input_state,
            measurement_strategy=MeasurementStrategy.probs(
                computation_space=ComputationSpace.FOCK
            )
        )

        # Calculate quantum output size
        from math import comb
        self.quantum_output_size = comb(q_modes + n_photons - 1, n_photons)
        print(f"Quantum output size: {self.quantum_output_size}")

        # Step 4: Combine classical and quantum features
        self.combined_size = n_features + self.quantum_output_size

        # Step 5: Temporal Convolutional Network
        self.tcn = TemporalConvNet(
            num_inputs=self.combined_size,
            num_channels=hidden_channels,
            kernel_size=kernel_size,
            dropout=dropout
        )

        # Step 6: Output projection
        self.output_projection = nn.Sequential(
            nn.Linear(hidden_channels[-1], hidden_channels[-1] // 2),
            nn.ReLU(),
            nn.Dropout(dropout),
            nn.Linear(hidden_channels[-1] // 2, n_features)
        )

        # Initialize parameters
        self._init_weights()

        # Device will be set during first forward pass
        self.device = None

    def _init_weights(self):
        """Initialize weights using Xavier initialization"""
        for module in self.modules():
            if isinstance(module, nn.Linear):
                nn.init.xavier_uniform_(module.weight)
                if module.bias is not None:
                    nn.init.constant_(module.bias, 0)
            elif isinstance(module, nn.Conv1d):
                nn.init.kaiming_normal_(module.weight, mode='fan_in', nonlinearity='relu')
                if module.bias is not None:
                    nn.init.constant_(module.bias, 0)

    def to(self, device):
        """Override to method to track device"""
        self.device = device
        return super().to(device)

    def forward(self, x):
        """
        Forward pass
        Args:
            x: Input tensor of shape [batch_size, seq_len, n_features]
        Returns:
            Predictions of shape [batch_size, seq_len, n_features]
        """
        # Track device
        if self.device is None:
            self.device = x.device

        batch_size, seq_len, _ = x.shape

        # Process each time step through quantum layer
        quantum_features = []
        for t in range(seq_len):
            # Get features for this time step
            x_t = x[:, t, :]  # [batch_size, n_features]

            # Compress features
            x_compressed = self.compressor(x_t)  # [batch_size, q_modes]
            x_scaled = self.scale_layer(x_compressed)

            # Get quantum features
            q_out = self.quantum_layer(x_scaled)  # [batch_size, quantum_output_size]

            # IMPORTANT: Ensure quantum output is on the same device as input
            q_out = q_out.to(self.device)

            quantum_features.append(q_out)

        # Stack quantum features
        quantum_stack = torch.stack(quantum_features, dim=1)  # [batch_size, seq_len, quantum_output_size]

        # Ensure quantum stack is on the same device as input
        quantum_stack = quantum_stack.to(self.device)

        # Combine classical and quantum features
        combined = torch.cat([x, quantum_stack], dim=-1)  # [batch_size, seq_len, combined_size]

        # TCN expects [batch_size, channels, seq_len]
        tcn_input = combined.transpose(1, 2)  # [batch_size, combined_size, seq_len]

        # Temporal convolution processing
        tcn_output = self.tcn(tcn_input)  # [batch_size, hidden_channels[-1], seq_len]

        # Transpose back to [batch_size, seq_len, hidden_channels[-1]]
        tcn_output = tcn_output.transpose(1, 2)  # [batch_size, seq_len, hidden_channels[-1]]

        # Generate predictions
        predictions = self.output_projection(tcn_output)  # [batch_size, seq_len, n_features]

        return predictions

def load_actual_data():
    """
    Load the actual dataset from the hackathon
    """
    try:
        import aqora_cli
        import polars as pl
        from aqora_cli.pyarrow import dataset

        print("Loading data from aqora_cli...")
        df_raw = pl.scan_pyarrow_dataset(dataset("quandela/challenge-swpations", "v0.0.0")).collect()
        df = df_raw.to_pandas()

        # Handle date column
        if 'Date' in df.columns:
            dates = df['Date']
            df = df.drop(columns=['Date'])

        print(f"Data loaded successfully! Shape: {df.shape}")
        print(f"Number of features: {df.shape[1]}")

        return df, dates if 'dates' in locals() else None

    except ImportError as e:
        print(f"Could not load actual data: {e}")
        print("Creating synthetic data for testing...")

        np.random.seed(42)
        n_samples = 200
        n_features = 200

        data = np.zeros((n_samples, n_features))

        # Generate prices with some correlation structure
        for i in range(1, n_samples):
            returns = np.random.randn(n_features) * 0.02
            data[i] = data[i-1] * 0.95 + returns * 0.05 + 0.0001

        # Ensure positivity
        data = np.abs(data) + 0.01

        df = pd.DataFrame(data, columns=[f'feature_{i}' for i in range(n_features)])

        print(f"Created sample data with shape: {df.shape}")
        return df, None

def prepare_data(df, sequence_length=10, test_size=0.2):
    """
    Prepare time series data for training
    """
    if isinstance(df, pd.DataFrame):
        data = df.values.astype(np.float32)
    else:
        data = df.astype(np.float32)

    print(f"Data shape: {data.shape}")
    print(f"Number of features: {data.shape[1]}")

    # Normalize the data
    scaler = StandardScaler()
    data_normalized = scaler.fit_transform(data)

    # Create sequences
    X, y = [], []
    for i in range(len(data_normalized) - sequence_length):
        X.append(data_normalized[i:i+sequence_length])
        y.append(data_normalized[i+sequence_length])

    X = np.array(X, dtype=np.float32)
    y = np.array(y, dtype=np.float32)

    print(f"Created {len(X)} sequences of length {sequence_length}")
    print(f"X shape: {X.shape}, y shape: {y.shape}")

    split_idx = int(len(X) * (1 - test_size))
    X_train, X_test = X[:split_idx], X[split_idx:]
    y_train, y_test = y[:split_idx], y[split_idx:]

    X_train = torch.FloatTensor(X_train)
    y_train = torch.FloatTensor(y_train)
    X_test = torch.FloatTensor(X_test)
    y_test = torch.FloatTensor(y_test)

    print(f"Training set: X {X_train.shape}, y {y_train.shape}")
    print(f"Test set: X {X_test.shape}, y {y_test.shape}")

    return X_train, y_train, X_test, y_test, scaler

def train_model(model, train_loader, val_loader, epochs=30, learning_rate=0.001):
    """
    Train the hybrid quantum-classical model
    """
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    model = model.to(device)
    print(f"Training on device: {device}")

    criterion = nn.MSELoss()
    optimizer = optim.Adam(model.parameters(), lr=learning_rate, weight_decay=1e-5)
    scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', patience=3, factor=0.5)

    train_losses = []
    val_losses = []

    for epoch in range(epochs):
        # Training phase
        model.train()
        train_loss = 0
        train_progress = tqdm(train_loader, desc=f'Epoch {epoch+1}/{epochs} [Train]', leave=False)

        for batch_X, batch_y in train_progress:
            # Move data to device
            batch_X = batch_X.to(device)
            batch_y = batch_y.to(device)

            optimizer.zero_grad()
            outputs = model(batch_X)

            # For prediction, we want to predict the next time step
            loss = criterion(outputs[:, -1, :], batch_y)
            loss.backward()

            # Gradient clipping
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            optimizer.step()

            train_loss += loss.item()
            train_progress.set_postfix({'loss': loss.item()})

        # Validation phase
        model.eval()
        val_loss = 0
        with torch.no_grad():
            for batch_X, batch_y in val_loader:
                batch_X = batch_X.to(device)
                batch_y = batch_y.to(device)
                outputs = model(batch_X)
                loss = criterion(outputs[:, -1, :], batch_y)
                val_loss += loss.item()

        # Calculate average losses
        train_loss /= len(train_loader)
        val_loss /= len(val_loader)
        train_losses.append(train_loss)
        val_losses.append(val_loss)

        # Update learning rate
        scheduler.step(val_loss)

        if (epoch + 1) % 5 == 0:
            print(f'Epoch [{epoch+1}/{epochs}], Train Loss: {train_loss:.6f}, Val Loss: {val_loss:.6f}')

    return train_losses, val_losses

def save_model(model, scaler, train_losses, val_losses, model_name="quantum_tcn_option_pricing_3photons"):
    """
    Save the trained model and associated data
    """
    # Create models directory if it doesn't exist
    if not os.path.exists('saved_models'):
        os.makedirs('saved_models')

    # Generate timestamp
    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")

    # Save model state dict
    model_path = f'saved_models/{model_name}_{timestamp}.pth'
    torch.save({
        'model_state_dict': model.state_dict(),
        'model_config': {
            'n_features': model.n_features,
            'q_modes': model.q_modes,
            'n_photons': model.n_photons,  # Now using the stored photon count
            'hidden_channels': model.hidden_channels,
            'kernel_size': model.kernel_size,
            'dropout': model.dropout
        },
        'train_losses': train_losses,
        'val_losses': val_losses,
        'timestamp': timestamp
    }, model_path)

    # Save scaler separately
    import joblib
    scaler_path = f'saved_models/scaler_{timestamp}.pkl'
    joblib.dump(scaler, scaler_path)

    print(f"\nModel saved to: {model_path}")
    print(f"Scaler saved to: {scaler_path}")

    return model_path, scaler_path

def main():
    """
    Main execution function
    """
    print("=" * 60)
    print("QUANTUM MACHINE LEARNING FOR OPTION PRICING (TCN VERSION WITH 3 PHOTONS)")
    print("=" * 60)

    # Step 1: Load data
    print("\n1. LOADING DATA")
    print("-" * 40)
    df, dates = load_actual_data()

    # Step 2: Prepare data
    print("\n2. PREPARING DATA")
    print("-" * 40)
    X_train, y_train, X_test, y_test, scaler = prepare_data(
        df, sequence_length=10, test_size=0.2
    )

    # Create data loaders
    train_dataset = TensorDataset(X_train, y_train)
    test_dataset = TensorDataset(X_test, y_test)

    train_loader = DataLoader(train_dataset, batch_size=8, shuffle=True)
    test_loader = DataLoader(test_dataset, batch_size=8, shuffle=False)

    print(f"Training samples: {len(X_train)}")
    print(f"Testing samples: {len(X_test)}")
    print(f"Sequence length: {X_train.shape[1]}")
    print(f"Features per time step: {X_train.shape[2]}")

    # Step 3: Initialize model
    print("\n3. INITIALIZING QUANTUM-CLASSICAL TCN WITH 3 PHOTONS")
    print("-" * 40)

    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

    model = QuantumFinancialTCN(
        n_features=X_train.shape[2],
        q_modes=6,
        n_photons=3,  # Changed from 2 to 3 photons
        hidden_channels=[64, 128, 64],  # TCN hidden channels
        kernel_size=3,                    # Kernel size for convolutions
        dropout=0.1                        # Dropout rate
    )
    model = model.to(device)

    total_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
    print(f"Total trainable parameters: {total_params:,}")

    print("\nTesting forward pass...")
    test_batch = next(iter(train_loader))[0][:2].to(device)
    with torch.no_grad():
        test_output = model(test_batch)
        print(f"Test input shape: {test_batch.shape}")
        print(f"Test output shape: {test_output.shape}")
        print(f"Test output range: [{test_output.min():.4f}, {test_output.max():.4f}]")

    print("\n4. TRAINING MODEL")
    print("-" * 40)
    train_losses, val_losses = train_model(
        model, train_loader, test_loader,
        epochs=20, learning_rate=0.001
    )

    print("\n5. VISUALIZING RESULTS")
    print("-" * 40)

    fig, axes = plt.subplots(1, 2, figsize=(15, 5))

    axes[0].plot(train_losses, label='Training Loss', linewidth=2)
    axes[0].plot(val_losses, label='Validation Loss', linewidth=2)
    axes[0].set_xlabel('Epoch')
    axes[0].set_ylabel('MSE Loss')
    axes[0].set_title('Training and Validation Loss (TCN with 3 Photons)')
    axes[0].legend()
    axes[0].grid(True, alpha=0.3)
    axes[0].set_yscale('log')

    # Plot sample predictions
    model.eval()
    with torch.no_grad():
        # Get a batch and move to device
        sample_X, sample_y = next(iter(test_loader))
        sample_X = sample_X.to(device)
        sample_y = sample_y.to(device)

        predictions = model(sample_X)

        pred_last = predictions[:, -1, :].cpu()  # Move back to CPU for plotting
        sample_y_cpu = sample_y.cpu()

        # Plot first 10 features for first 3 samples
        n_samples_plot = min(3, len(sample_X))
        n_features_plot = min(10, sample_X.shape[2])

        for i in range(n_samples_plot):
            axes[1].plot(range(n_features_plot),
                        sample_y_cpu[i, :n_features_plot].numpy(),
                        'o-', label=f'Actual {i+1}', alpha=0.7, markersize=4)
            axes[1].plot(range(n_features_plot),
                        pred_last[i, :n_features_plot].numpy(),
                        'x--', label=f'Pred {i+1}', alpha=0.7, markersize=4)

        axes[1].set_xlabel('Feature Index')
        axes[1].set_ylabel('Normalized Price')
        axes[1].set_title('Sample Predictions vs Actual (Next Time Step)')
        axes[1].legend(loc='center left', bbox_to_anchor=(1, 0.5), fontsize=8)
        axes[1].grid(True, alpha=0.3)

    plt.tight_layout()
    plt.savefig('option_pricing_tcn_results_3photons.png', dpi=150, bbox_inches='tight')
    plt.show()

    # Step 6: Final evaluation
    print("\n6. FINAL EVALUATION")
    print("-" * 40)
    model.eval()
    with torch.no_grad():
        test_loss = 0
        all_predictions = []
        all_actuals = []

        for batch_X, batch_y in test_loader:
            batch_X = batch_X.to(device)
            batch_y = batch_y.to(device)

            outputs = model(batch_X)
            pred_last = outputs[:, -1, :]
            loss = nn.MSELoss()(pred_last, batch_y)
            test_loss += loss.item()

            all_predictions.append(pred_last.cpu().numpy())
            all_actuals.append(batch_y.cpu().numpy())

        test_loss /= len(test_loader)

        # Calculate additional metrics
        all_predictions = np.concatenate(all_predictions, axis=0)
        all_actuals = np.concatenate(all_actuals, axis=0)

        mae = np.mean(np.abs(all_predictions - all_actuals))
        mape = np.mean(np.abs((all_predictions - all_actuals) / (all_actuals + 1e-8))) * 100

        print(f"Test MSE:  {test_loss:.6f}")
        print(f"Test MAE:  {mae:.6f}")
        print(f"Test MAPE: {mape:.2f}%")

    # Step 7: Save the model
    print("\n7. SAVING MODEL")
    print("-" * 40)
    model_path, scaler_path = save_model(model, scaler, train_losses, val_losses)

    print("\n" + "=" * 60)
    print("TRAINING COMPLETE!")
    print("=" * 60)

    return model, scaler, model_path, scaler_path

if __name__ == "__main__":
    # Run the main training function
    trained_model, fitted_scaler, model_path, scaler_path = main()

    print("\n" + "=" * 60)
    print("EXAMPLE USAGE FOR PREDICTION")
    print("=" * 60)
    print(f"""
    # To load and use the saved model:

    # Load the model
    import torch
    import joblib

    # Load model configuration and state dict
    checkpoint = torch.load('{model_path}')
    model = QuantumFinancialTCN(
        n_features=checkpoint['model_config']['n_features'],
        q_modes=checkpoint['model_config']['q_modes'],
        n_photons=checkpoint['model_config']['n_photons'],  # Will be 3
        hidden_channels=checkpoint['model_config']['hidden_channels'],
        kernel_size=checkpoint['model_config']['kernel_size'],
        dropout=checkpoint['model_config']['dropout']
    )
    model.load_state_dict(checkpoint['model_state_dict'])
    model.eval()

    # Load the scaler
    scaler = joblib.load('{scaler_path}')

    # Make predictions on new data
    with torch.no_grad():
        # Prepare your data (same format as training)
        new_data = torch.FloatTensor(your_normalized_data).unsqueeze(0)  # [1, seq_len, n_features]
        predictions = model(new_data)  # [1, seq_len, n_features]
        next_step_pred = predictions[0, -1, :].numpy()

        # Inverse transform to get actual prices
        actual_prices = scaler.inverse_transform(next_step_pred.reshape(1, -1))
    """)
# Out:
# ============================================================
# QUANTUM MACHINE LEARNING FOR OPTION PRICING (TCN VERSION WITH 3 PHOTONS)
# ============================================================
#
# 1. LOADING DATA
# ----------------------------------------
# Loading data from aqora_cli...
# Data loaded successfully! Shape: (494, 224)
# Number of features: 224
#
# 2. PREPARING DATA
# ----------------------------------------
# Data shape: (494, 224)
# Number of features: 224
# Created 484 sequences of length 10
# X shape: (484, 10, 224), y shape: (484, 224)
# Training set: X torch.Size([387, 10, 224]), y torch.Size([387, 224])
# Test set: X torch.Size([97, 10, 224]), y torch.Size([97, 224])
# Training samples: 387
# Testing samples: 97
# Sequence length: 10
# Features per time step: 224
#
# 3. INITIALIZING QUANTUM-CLASSICAL TCN WITH 3 PHOTONS
# ----------------------------------------
# Creating quantum circuit with 6 modes, 3 photons...
# Input state: [1, 1, 1, 0, 0, 0]
# Quantum output size: 56
# Total trainable parameters: 237,988
#
# Testing forward pass...
# Test input shape: torch.Size([2, 10, 224])
# Test output shape: torch.Size([2, 10, 224])
# Test output range: [-1.7735, 2.0542]
#
# 4. TRAINING MODEL
# ----------------------------------------
# Training on device: cuda
# Epoch [5/20], Train Loss: 0.186062, Val Loss: 0.124810
# Epoch [10/20], Train Loss: 0.114426, Val Loss: 0.081717
# Epoch [15/20], Train Loss: 0.099147, Val Loss: 0.081557
# Epoch [20/20], Train Loss: 0.077539, Val Loss: 0.099971
#
# 5. VISUALIZING RESULTS
# ----------------------------------------
# 6. FINAL EVALUATION
# ----------------------------------------
# Test MSE:  0.099971
# Test MAE:  0.240121
# Test MAPE: 160.28%
#
# 7. SAVING MODEL
# ----------------------------------------
#
# Model saved to: saved_models/quantum_tcn_option_pricing_3photons_20260303_084838.pth
# Scaler saved to: saved_models/scaler_20260303_084838.pkl
#
# ============================================================
# TRAINING COMPLETE!
# ============================================================
#
# ============================================================
# EXAMPLE USAGE FOR PREDICTION
# ============================================================
#
#     # To load and use the saved model:
#
#     # Load the model
#     import torch
#     import joblib
#
#     # Load model configuration and state dict
#     checkpoint = torch.load('saved_models/quantum_tcn_option_pricing_3photons_20260303_084838.pth')
#     model = QuantumFinancialTCN(
#         n_features=checkpoint['model_config']['n_features'],
#         q_modes=checkpoint['model_config']['q_modes'],
#         n_photons=checkpoint['model_config']['n_photons'],  # Will be 3
#         hidden_channels=checkpoint['model_config']['hidden_channels'],
#         kernel_size=checkpoint['model_config']['kernel_size'],
#         dropout=checkpoint['model_config']['dropout']
#     )
#     model.load_state_dict(checkpoint['model_state_dict'])
#     model.eval()
#
#     # Load the scaler
#     scaler = joblib.load('saved_models/scaler_20260303_084838.pkl')
#
#     # Make predictions on new data
#     with torch.no_grad():
#         # Prepare your data (same format as training)
#         new_data = torch.FloatTensor(your_normalized_data).unsqueeze(0)  # [1, seq_len, n_features]
#         predictions = model(new_data)  # [1, seq_len, n_features]
#         next_step_pred = predictions[0, -1, :].numpy()
#
#         # Inverse transform to get actual prices
#         actual_prices = scaler.inverse_transform(next_step_pred.reshape(1, -1))
